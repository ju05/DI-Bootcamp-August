# %%
import matplotlib.pyplot as plt

# %%
day = [1,2,3,4,5,6,7,8]
temp = [24,26,26,27,23,21,20,24]
plt.plot(day, temp, color='green', linewidth=2, marker='o')
plt.show()

# %%
import pandas as pd

# Load the Titanic dataset
titanic_data = pd.read_csv('train.csv')

# %%
plt.bar(list(titanic_data['Sex'].unique()),titanic_data['Sex'].value_counts(),color=['red', 'green'] )
plt.title('Count of People on the Titanic by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
titanic_data['Age'].max()
# Out:
# 80.0

# %%
plt.hist(titanic_data['Age'],8)
plt.show()

# %%
plt.pie(titanic_data['Pclass'].value_counts(), autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7b903b33c5c0>,
# ...
#  [Text(-0.17571619097547903, 1.085874679799225, ''),
#   Text(-0.5160760536623383, -0.9714244730478574, ''),
#   Text(0.8765111790709129, -0.6646263258130227, '')],
#  [Text(-0.09584519507753402, 0.5922952798904862, '55.1%'),
#   Text(-0.2814960292703663, -0.5298678943897404, '24.2%'),
#   Text(0.47809700676595246, -0.3625234504434669, '20.7%')])
